# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sms
from statsmodels.tsa.ar_model import AutoReg

# %%
df=pd.read_csv("D:\\python datasets\\Time series data\\all_stocks_1yr.csv",index_col=0,parse_dates=True)

# %%
df
# Out:
#               Open    High     Low   Close   Volume Name
# Date
# 2016-08-12  181.47  181.47  179.90  180.27  1232856  MMM
# 2016-08-15  181.00  181.39  180.46  180.56  1268247  MMM
# 2016-08-16  180.12  180.33  179.21  179.25  1363554  MMM
# 2016-08-17  178.67  180.09  178.32  179.87  1358528  MMM
# 2016-08-18  179.70  179.70  178.58  179.18  1088677  MMM
# ...            ...     ...     ...     ...      ...  ...
# 2017-08-07   62.12   62.34   61.25   61.83  4208287  ZTS
# 2017-08-08   60.49   61.00   59.50   60.00  4663668  ZTS
# 2017-08-09   59.95   60.87   59.76   60.81  4017297  ZTS
# 2017-08-10   60.87   61.37   59.71   59.74  2690725  ZTS
# 2017-08-11   60.05   60.22   59.64   59.73  2285863  ZTS
#
# [126217 rows x 6 columns]

# %%
df.head()
# Out:
#               Open    High     Low   Close   Volume Name
# Date
# 2016-08-12  181.47  181.47  179.90  180.27  1232856  MMM
# 2016-08-15  181.00  181.39  180.46  180.56  1268247  MMM
# 2016-08-16  180.12  180.33  179.21  179.25  1363554  MMM
# 2016-08-17  178.67  180.09  178.32  179.87  1358528  MMM
# 2016-08-18  179.70  179.70  178.58  179.18  1088677  MMM

# %%
df.isnull().sum()
# Out:
# Open      380
# High      206
# Low       224
# Close       0
# Volume      0
# Name        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 126217 entries, 2016-08-12 to 2017-08-11
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Open    125837 non-null  float64
#  1   High    126011 non-null  float64
#  2   Low     125993 non-null  float64
#  3   Close   126217 non-null  float64
#  4   Volume  126217 non-null  int64
#  5   Name    126217 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 6.7+ MB

# %%
df.tail()
# Out:
#              Open   High    Low  Close   Volume Name
# Date
# 2017-08-07  62.12  62.34  61.25  61.83  4208287  ZTS
# 2017-08-08  60.49  61.00  59.50  60.00  4663668  ZTS
# 2017-08-09  59.95  60.87  59.76  60.81  4017297  ZTS
# 2017-08-10  60.87  61.37  59.71  59.74  2690725  ZTS
# 2017-08-11  60.05  60.22  59.64  59.73  2285863  ZTS

# %%
from datetime import datetime

# %%
df2=df.iloc[:,0:1]

# %%
df2
# Out:
#               Open
# Date
# 2016-08-12  181.47
# 2016-08-15  181.00
# 2016-08-16  180.12
# 2016-08-17  178.67
# 2016-08-18  179.70
# ...            ...
# 2017-08-07   62.12
# 2017-08-08   60.49
# 2017-08-09   59.95
# 2017-08-10   60.87
# 2017-08-11   60.05
#
# [126217 rows x 1 columns]

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
